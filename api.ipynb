# %%
import MetaTrader5 as mt5  # pip install MetaTrader5
import pandas as pd  # pip install pandas
import plotly.express as px  # pip install plotly
from datetime import datetime, timedelta
from mt5_config import login_number, path

# %%
# start the platform with initialize()
result = mt5.initialize(path)
if login_number == mt5.account_info().login and result is True:
    print('Connection with MT5 established')
else:
    print('Connection failed')
    mt5.shutdown()
# Out:
# Connection with MT5 established

# %%
result = mt5.initialize()
result
# Out:
# True

# %%
account_info = mt5.account_info()
print(account_info)

# getting specific account data
login = account_info.login
balance = account_info.balance
equity = account_info.equity

leverage = account_info.leverage

print()
print('login: ', login)
print('balance: ', balance)
print('equity: ', equity)
print('leverage: ', leverage)
# Out:
# AccountInfo(login=52612537, trade_mode=0, leverage=30, limit_orders=200, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=100000.0, credit=0.0, profit=0.0, equity=100000.0, margin=0.0, margin_free=100000.0, margin_level=0.0, margin_so_call=100.0, margin_so_so=0.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='pei xin chen', server='ICMarketsSC-Demo', currency='USD', company='Raw Trading Ltd')
#
# login:  52612537
# balance:  100000.0
# equity:  100000.0
# leverage:  30

# %%
num_symbols = mt5.symbols_total()

num_symbols
# Out:
# 2017

# %%
symbols = mt5.symbols_get()
symbols
# Out:
# (SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1764094988, digits=5, spread=0, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.15713, bidhigh=1.15841, bidlow=1.15116, ask=1.15713, askhigh=1.15841, asklow=1.15116, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0, trade_tick_value_profit=1.0, trade_tick_value_loss=1.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=200.0, volu
# ...

# %%
symbol_info = mt5.symbol_info("EURUSD")._asdict()
symbol_info
# Out:
# {'custom': False,
#  'chart_mode': 0,
#  'select': True,
#  'visible': True,
#  'session_deals': 0,
#  'session_buy_orders': 0,
#  'session_sell_orders': 0,
#  'volume': 0,
#  'volumehigh': 0,
#  'volumelow': 0,
#  'time': 1764095165,
#  'digits': 5,
#  'spread': 0,
#  'spread_float': True,
#  'ticks_bookdepth': 10,
#  'trade_calc_mode': 0,
#  'trade_mode': 4,
#  'start_time': 0,
#  'expiration_time': 0,
#  'trade_stops_level': 0,
#  'trade_freeze_level': 0,
#  'trade_exemode': 2,
#  'swap_mode': 1,
#  'swap_rollover3days': 3,
#  'margin_hedged_use_leg': False,
#  'expiration_mode': 15,
#  'filling_mode': 2,
#  'order_mode': 127,
#  'order_gtc_mode': 0,
#  'option_mode': 0,
#  'option_right': 0,
#  'bid': 1.15689,
#  'bidhigh': 1.15841,
#  'bidlow': 1.15116,
#  'ask': 1.15689,
#  'askhigh': 1.15841,
#  'asklow': 1.15116,
#  'last': 0.0,
#  'lasthigh': 0.0,
#  'lastlow': 0.0,
#  'volume_real': 0.0,
#  'volumehigh_real': 0.0,
#  'volumelow_real': 0.0,
#  'option_strike': 0.0,
# ...

# %%
symbol_price = mt5.symbol_info_tick("EURUSD")._asdict()

timestamp = symbol_price['time']
print('Timestamp', timestamp)
datetime_value = datetime.fromtimestamp(timestamp)
print('Datetime', datetime_value)

print('---\n')

symbol_price
# Out:
# Timestamp 1764095209
# Datetime 2025-11-26 02:26:49
# ---
# {'time': 1764095209,
#  'bid': 1.15682,
#  'ask': 1.15682,
#  'last': 0.0,
#  'volume': 0,
#  'time_msc': 1764095209267,
#  'flags': 6,
#  'volume_real': 0.0}

# %%
rates = mt5.copy_rates_range("EURUSD", mt5.TIMEFRAME_D1, datetime.now() - timedelta(days=365), datetime.now())
print(rates)

ohlc_data = pd.DataFrame(rates)

fig = px.line(ohlc_data, x=ohlc_data['time'], y=ohlc_data['close'])
fig.show()

ohlc_data
# Out:
# [(1732579200, 1.04932, 1.05448, 1.04251, 1.04893,  79460, 0, 0)
#  (1732665600, 1.0483 , 1.05877, 1.04742, 1.05665,  69992, 0, 0)
#  (1732752000, 1.05658, 1.05698, 1.05275, 1.05538,  44088, 0, 0)
#  (1732838400, 1.05489, 1.05973, 1.05416, 1.05759,  70306, 0, 0)
#  (1733097600, 1.05615, 1.05704, 1.04606, 1.04977,  80068, 0, 0)
#  (1733184000, 1.04974, 1.05351, 1.04808, 1.05094,  63878, 0, 0)
#  (1733270400, 1.05074, 1.05442, 1.04723, 1.051  ,  69809, 0, 0)
#  (1733356800, 1.05076, 1.05896, 1.05039, 1.05874,  58073, 0, 0)
#  (1733443200, 1.05835, 1.06298, 1.05423, 1.05678,  61119, 0, 0)
#  (1733702400, 1.05555, 1.05943, 1.05322, 1.05536,  54284, 0, 0)
#  (1733788800, 1.05531, 1.05683, 1.04985, 1.05272,  53675, 0, 0)
#  (1733875200, 1.05271, 1.05393, 1.04802, 1.04957,  64471, 0, 0)
#  (1733961600, 1.04931, 1.05309, 1.04638, 1.04663,  69557, 0, 0)
#  (1734048000, 1.04664, 1.05243, 1.04531, 1.05031,  56891, 0, 0)
#  (1734307200, 1.0485 , 1.05248, 1.04746, 1.05114,  53594, 0, 0)
# ...

# %%
ticks = mt5.copy_ticks_range("EURUSD", datetime.now() - timedelta(days=1), datetime.now(), mt5.COPY_TICKS_ALL)
print(ticks)

tick_data = pd.DataFrame(ticks)

fig = px.line(tick_data, x='time', y=['bid', 'ask'])
fig.show()

tick_data
# Out:
# [(1764001849, 1.153  , 1.153  , 0., 0, 1764001849066, 134, 0.)
#  (1764001850, 1.15306, 1.15306, 0., 0, 1764001850666, 134, 0.)
#  (1764001851, 1.15305, 1.15305, 0., 0, 1764001851467, 134, 0.) ...
#  (1764088241, 1.15549, 1.15549, 0., 0, 1764088241066,   6, 0.)
#  (1764088242, 1.1555 , 1.1555 , 0., 0, 1764088242070,   6, 0.)
#  (1764088242, 1.15552, 1.15552, 0., 0, 1764088242267,   6, 0.)]
#              time      bid      ask  last  volume       time_msc  flags  \
# 0      1764001849  1.15300  1.15300   0.0       0  1764001849066    134
# 1      1764001850  1.15306  1.15306   0.0       0  1764001850666    134
# 2      1764001851  1.15305  1.15305   0.0       0  1764001851467    134
# 3      1764001851  1.15304  1.15304   0.0       0  1764001851869    134
# 4      1764001856  1.15295  1.15295   0.0       0  1764001856081    134
# ...           ...      ...      ...   ...     ...            ...    ...
# 42661  1764088240  1.15549  1.15549   0.0       0  1764088240267      6
# ...

# %%
num_orders = mt5.orders_total()
num_orders
# Out:
# 2

# %%
orders = mt5.orders_get()
orders
# Out:
# (TradeOrder(ticket=1338071751, time_setup=1764095899, time_setup_msc=1764095899556, time_done=0, time_done_msc=0, time_expiration=0, type=3, type_time=0, type_filling=2, state=1, magic=0, position_id=0, position_by_id=0, reason=0, volume_initial=1.0, volume_current=1.0, price_open=1.16014, sl=0.0, tp=0.0, price_current=1.15585, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),
#  TradeOrder(ticket=1338073018, time_setup=1764095957, time_setup_msc=1764095957238, time_done=0, time_done_msc=0, time_expiration=0, type=2, type_time=0, type_filling=2, state=1, magic=0, position_id=0, position_by_id=0, reason=0, volume_initial=1.0, volume_current=1.0, price_open=1.15271, sl=0.0, tp=0.0, price_current=1.15585, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''))

# %%
num_positions = mt5.positions_total()
num_positions
# Out:
# 1

# %%
positions = mt5.positions_get()
positions
# Out:
# (TradePosition(ticket=1338075845, time=1764096060, time_msc=1764096060797, time_update=1764096060, time_update_msc=1764096060797, type=0, magic=0, identifier=1338075845, reason=0, volume=1.0, price_open=1.15584, sl=0.0, tp=0.0, price_current=1.15574, swap=0.0, profit=-10.0, symbol='EURUSD', comment='', external_id=''),)

# %%
num_order_history = mt5.history_orders_total(datetime.now() - timedelta(days=7), datetime.now() + timedelta(hours=3))
num_order_history
# Out:
# 1

# %%
order_history = mt5.history_orders_get(datetime.now() - timedelta(days=7), datetime.now() + timedelta(hours=3))
order_history
# Out:
# (TradeOrder(ticket=1338075845, time_setup=1764096060, time_setup_msc=1764096060546, time_done=1764096060, time_done_msc=1764096060797, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=1338075845, position_by_id=0, reason=0, volume_initial=1.0, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.15584, price_stoplimit=0.0, symbol='EURUSD', comment='', external_id=''),)

# %%
num_deal_history = mt5.history_deals_total(datetime.now() - timedelta(days=7), datetime.now() + timedelta(hours=3))
num_deal_history
# Out:
# 2

# %%
deal_history = mt5.history_deals_get(datetime.now() - timedelta(days=7), datetime.now() + timedelta(hours=3))
deal_history
# Out:
# (TradeDeal(ticket=1086539178, order=0, time=1763632350, time_msc=1763632350797, type=2, entry=0, magic=0, position_id=0, reason=0, volume=0.0, price=0.0, commission=0.0, swap=0.0, profit=100000.0, fee=0.0, symbol='', comment='Demo deposit', external_id=''),
#  TradeDeal(ticket=1095276228, order=1338075845, time=1764096060, time_msc=1764096060797, type=0, entry=0, magic=0, position_id=1338075845, reason=0, volume=1.0, price=1.15584, commission=-3.5, swap=0.0, profit=0.0, fee=0.0, symbol='EURUSD', comment='', external_id=''))

# %%
request = {
    "action": mt5.TRADE_ACTION_DEAL,
    "symbol": "EURUSD",
    "volume": 2.0, # FLOAT
    "type": mt5.ORDER_TYPE_BUY,
    "price": mt5.symbol_info_tick("EURUSD").ask,
    "sl": 0.0, # FLOAT
    "tp": 0.0, # FLOAT
    "deviation": 20, # INTERGER
    "magic": 1, # INTERGER
    "comment": "python script open",
    "type_time": mt5.ORDER_TIME_GTC,
    "type_filling": mt5.ORDER_FILLING_IOC,
}

order = mt5.order_send(request)

last_ticket = order.order
print('last ticket', last_ticket)

print(order)
# Out:
# last ticket 1338092294
# OrderSendResult(retcode=10009, deal=1095291324, order=1338092294, volume=2.0, price=1.15558, bid=1.15558, ask=1.15558, comment='Request executed', request_id=601666030, retcode_external=0, request=TradeRequest(action=1, magic=1, order=0, symbol='EURUSD', volume=2.0, price=1.15558, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))

# %%
request = {
    "action": mt5.TRADE_ACTION_DEAL,
    "symbol": "EURUSD",
    "volume": 2.0, # FLOAT
    "type": mt5.ORDER_TYPE_SELL,
    "position": 1338092294, # select the position you want to close
    "price": mt5.symbol_info_tick("EURUSD").bid,
    "sl": 0.0, # FLOAT
    "tp": 0.0, # FLOAT
    "deviation": 20, # INTERGER
    "magic": 1, # INTERGER
    "comment": "python script open",
    "type_time": mt5.ORDER_TIME_GTC,
    "type_filling": mt5.ORDER_FILLING_IOC,
}

order = mt5.order_send(request)
print(order)
# Out:
# OrderSendResult(retcode=10009, deal=1095298396, order=1338099932, volume=2.0, price=1.1555900000000001, bid=1.1555900000000001, ask=1.1555900000000001, comment='Request executed', request_id=601666031, retcode_external=0, request=TradeRequest(action=1, magic=1, order=0, symbol='EURUSD', volume=2.0, price=1.15557, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='python script open', position=1338092294, position_by=0))
